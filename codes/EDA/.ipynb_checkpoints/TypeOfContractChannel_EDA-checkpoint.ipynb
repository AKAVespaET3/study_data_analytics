# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font',family='Malgun Gothic')
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### load datasets

# %%
df_TOCC = pd.read_csv('../../datasets/TypeOfContractChannel.csv')
df_TOCC[:2]
# Out:
#          id type_of_contract type_of_contract2 channel    datetime  Term  \
# 0  66758234               렌탈            Normal  서비스 방문  2019-10-20    60
# 1  66755948               렌탈  Extension_Rental  서비스 방문  2019-10-20    60
#
#   payment_type product  amount state  overdue_count overdue  credit rating  \
# 0          CMS      K1   96900  계약확정              0      없음            9.0
# 1         카드이체      K1  102900  계약확정              0      없음            2.0
#
#     bank cancellation   age  Mileage
# 0  새마을금고           정상  43.0   1862.0
# 1   현대카드           정상  62.0   2532.0

# %% [markdown]
# ### 분석 대상
# - 궁금한 점 : (한 건에 거래 내역당 총합에 영향을 준 내용은 무엇인가?)
# - 목표 변수 설정 : amount
# - 설명 변수 설정 : type_of_contract, datetime, product, age

# %%
df_TOCC.columns
# Out:
# Index(['id', 'type_of_contract', 'type_of_contract2', 'channel', 'datetime',
#        'Term', 'payment_type', 'product', 'amount', 'state', 'overdue_count',
#        'overdue', 'credit rating', 'bank', 'cancellation', 'age', 'Mileage'],
#       dtype='object')

# %% [markdown]
# ### EDA 전략
#
# 해당 변수(목표와 설명) 선택
# - 이상치와 결측치 처리

# %%
df_TOCC_choose = df_TOCC[['type_of_contract', 'datetime', 'product', 'amount', 'age' ]]
df_TOCC_choose.head(2)
# Out:
#   type_of_contract    datetime product  amount   age
# 0               렌탈  2019-10-20      K1   96900  43.0
# 1               렌탈  2019-10-20      K1  102900  62.0

# %%
# df_TOCC_choose.info()
# df_TOCC_choose.isnull().sum()
# df_TOCC_choose = df_TOCC_choose.dropna()
df_TOCC_choose.isnull().sum()
# Out:
# type_of_contract        4
# datetime                0
# product                 1
# amount                  0
# age                 10795
# dtype: int64

# %% [markdown]
# #### 범주형과 연속형(순서형)으로 dtype변형

# %%
df_TOCC_choose['datetime'] = pd.to_datetime(df_TOCC_choose['datetime'])
# Out:
# C:\Users\01-10\AppData\Local\Temp\ipykernel_11420\3979754315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TOCC_choose['datetime'] = pd.to_datetime(df_TOCC_choose['datetime'])

# %%
df_TOCC_choose.dtypes
# Out:
# type_of_contract            object
# datetime            datetime64[ns]
# product                     object
# amount                       int64
# age                        float64
# dtype: object

# %%
# df_TOCC_choose.describe()
df_TOCC_choose.describe(include='all')
# Out:
# C:\Users\01-10\AppData\Local\Temp\ipykernel_11420\318549244.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_TOCC_choose.describe(include='all')
#        type_of_contract             datetime product         amount  \
# count             51300                51304   51303   51304.000000
# unique                2                  101       6            NaN
# top                  렌탈  2019-10-29 00:00:00      K1            NaN
# freq              46481                  817   39134            NaN
# first               NaN  2019-10-20 00:00:00     NaN            NaN
# last                NaN  2020-02-03 00:00:00     NaN            NaN
# mean                NaN                  NaN     NaN   93994.980021
# std                 NaN                  NaN     NaN   15305.147334
# min                 NaN                  NaN     NaN   54603.000000
# 25%                 NaN                  NaN     NaN   81900.000000
# 50%                 NaN                  NaN     NaN   96900.000000
# 75%                 NaN                  NaN     NaN   98400.000000
# max                 NaN                  NaN     NaN  215700.000000
#
#                  age
# count   40509.000000
# unique           NaN
# top              NaN
# freq             NaN
# first            NaN
# last             NaN
# mean       46.608285
# std        13.465977
# min        20.000000
# 25%        37.000000
# 50%        46.000000
# 75%        56.000000
# max       107.000000

# %% [markdown]
# #### 변수간에 상관성 확인
# - 목표 변수는 정규화 여부 판단
# - 목표 변수와 각 설명 변수 간에 관계 확인

# %% [markdown]
# #### 보고서
# - 변수간 상관성 확인용

# %%
sns.histplot(data=df_TOCC_choose, x='amount', kde=True)
# Out:
# <Axes: xlabel='amount', ylabel='Count'>

# %%
# 연속형 / 연속형 : 상관계수
df_TOCC_choose.corr() #관계성 있을 경우 pairplot()
# Out:
# C:\Users\01-10\AppData\Local\Temp\ipykernel_11420\2682486231.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_TOCC_choose.corr() #관계성 있을 경우 pairplot()
#           amount       age
# amount  1.000000 -0.003537
# age    -0.003537  1.000000

# %%
# 범주형 / 연속형 : 최상/최하 갯수 선택
# 항목 2개 이상 필요
sns.barplot(data=df_TOCC_choose, x='type_of_contract', y='amount')
# Out:
# <Axes: xlabel='type_of_contract', ylabel='amount'>

# %%
sns.barplot(data=df_TOCC_choose, x='product', y='amount')
# Out:
# <Axes: xlabel='product', ylabel='amount'>

# %%
## 변수 안에서 원하는 항목 필터링
conditions = (df_TOCC_choose['product'] == 'K4') | (df_TOCC_choose['product'] == 'K5') | (df_TOCC_choose['product'] == 'K6')
df_TOCC_choose_product = df_TOCC_choose.loc[conditions]

# %%
df_TOCC_choose_product[:2]
# Out:
#     type_of_contract   datetime product  amount   age
# 58                렌탈 2019-10-21      K4  126900  28.0
# 110               렌탈 2019-10-21      K4  125700  23.0

# %%
sns.barplot(data=df_TOCC_choose_product, x='product', y='amount')
# Out:
# <Axes: xlabel='product', ylabel='amount'>

# %%
## 순서형 / 연속형 
sns.lineplot(data=df_TOCC_choose_product, x='datetime',y='amount')
# Out:
# <Axes: xlabel='datetime', ylabel='amount'>

# %%
## .loc[row_indexer,col_indexer] = value instead 컬럼이 없는 경우 붙임, 있는 경우 [] 붙임
# df_TOCC_choose_product['datetime'].dt.day_name()
df_TOCC_choose_product['day_name'] = df_TOCC_choose_product['datetime'].dt.day_name() #그 날짜가 특정 요일로 바뀜 요일별로 분석가능
df_TOCC_choose_product['day_name'].value_counts()
# Out:
# C:\Users\01-10\AppData\Local\Temp\ipykernel_11420\789414889.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TOCC_choose_product['day_name'] = df_TOCC_choose_product['datetime'].dt.day_name() #그 날짜가 특정 요일로 바뀜 요일별로 분석가능
# Thursday     205
# Friday       188
# Tuesday      184
# Monday       173
# Wednesday    173
# Sunday       163
# Saturday       6
# Name: day_name, dtype: int64

# %%
# 범주형 / 연속형
sns.barplot(data=df_TOCC_choose_product, x='day_name', y='amount')
# Out:
# <Axes: xlabel='day_name', ylabel='amount'>

# %% [markdown]
# #### 보고서
# - 변수간 상관성 확인용
#     - 목표 변수 : 비정규 분
#     - 설명 변수
#         - type_of_contract(범주형) : 2개 항목
#         - product (범주형) : 상위 3개 항목
#         - age : 상관 개수가 -0.003539 < 0.5 여서 설명 변수 채택 어려움.
#         - datetime(순서형) : 분포 특성상 요일별 변환
#         - day_name : 요일별 분석을 특성상 컴럼 추가
